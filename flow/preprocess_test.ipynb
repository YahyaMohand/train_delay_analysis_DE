# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../train_delay/All Delays 2018-19.csv')
data
# Out:
#        FINANCIAL_YEAR_AND_PERIOD ORIGIN_DEPARTURE_DATE  \
# 0                    2018/19_P01             01-APR-18
# 1                    2018/19_P01             01-APR-18
# 2                    2018/19_P01             01-APR-18
# 3                    2018/19_P01             01-APR-18
# 4                    2018/19_P01             01-APR-18
# ...                          ...                   ...
# 490313               2018/19_P01             28-APR-18
# 490314               2018/19_P01             28-APR-18
# 490315               2018/19_P01             28-APR-18
# 490316               2018/19_P01             28-APR-18
# 490317               2018/19_P01             28-APR-18
#
#        TRUST_TRAIN_ID_AFFECTED  PLANNED_ORIG_LOC_CODE_AFF  \
# 0                   011B44MN01                       1100
# 1                   011E17MF01                       1100
# 2                   011M16MZ01                       1100
# 3                   011M16MZ01                       1100
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490318 entries, 0 to 490317
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   FINANCIAL_YEAR_AND_PERIOD       490318 non-null  object
#  1   ORIGIN_DEPARTURE_DATE           490318 non-null  object
#  2   TRUST_TRAIN_ID_AFFECTED         490318 non-null  object
#  3   PLANNED_ORIG_LOC_CODE_AFF       490318 non-null  int64
#  4   PLANNED_ORIG_GBTT_DATETIME_AFF  366415 non-null  object
#  5   PLANNED_ORIG_WTT_DATETIME_AFF   490318 non-null  object
#  6   PLANNED_DEST_LOC_CODE_AFFECTED  490318 non-null  int64
#  7   PLANNED_DEST_GBTT_DATETIME_AFF  366415 non-null  object
#  8   PLANNED_DEST_WTT_DATETIME_AFF   490318 non-null  object
#  9   TRAIN_SERVICE_CODE_AFFECTED     490291 non-null  float64
#  10  SERVICE_GROUP_CODE_AFFECTED     490291 non-null  object
#  11  OPERATOR_AFFECTED               490291 non-null  object
# ...

# %%
data.isnull().sum(axis = 0)
# Out:
# FINANCIAL_YEAR_AND_PERIOD              0
# ORIGIN_DEPARTURE_DATE                  0
# TRUST_TRAIN_ID_AFFECTED                0
# PLANNED_ORIG_LOC_CODE_AFF              0
# PLANNED_ORIG_GBTT_DATETIME_AFF    123903
# PLANNED_ORIG_WTT_DATETIME_AFF          0
# PLANNED_DEST_LOC_CODE_AFFECTED         0
# PLANNED_DEST_GBTT_DATETIME_AFF    123903
# PLANNED_DEST_WTT_DATETIME_AFF          0
# TRAIN_SERVICE_CODE_AFFECTED           27
# SERVICE_GROUP_CODE_AFFECTED           27
# OPERATOR_AFFECTED                     27
# ENGLISH_DAY_TYPE                       0
# APP_TIMETABLE_FLAG_AFF                 0
# TRAIN_SCHEDULE_TYPE_AFFECTED           0
# TRACTION_TYPE_AFFECTED              5130
# TRAILING_LOAD_AFFECTED            434279
# TIMING_LOAD_AFFECTED              357969
# UNIT_CLASS_AFFECTED               401292
# INCIDENT_NUMBER                        0
# INCIDENT_CREATE_DATE                   0
# INCIDENT_START_DATETIME                0
# INCIDENT_END_DATETIME                  0
# ...
